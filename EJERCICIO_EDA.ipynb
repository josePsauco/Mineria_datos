# %% [markdown]
# # EJERCICIOS MINERIA DE DATOS

# %% [markdown]
# 0. importe pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %% [markdown]
# 1. leer un archivo csv (breast-cancer-wisconsin.data.txt situado en el dataset cancer) en un DataFrame llamado datos. Coloquele los nombres de las columnas como esta especificado en el archivo breast-cancer-wisconsin.names.txt

# %%
data = pd.read_csv('c:/Users/MANOLO/Downloads/breast-cancer-wisconsin.data.txt', header = None, names = ["Sample code number","Clump Thickness","Uniformity of Cell Size","Uniformity of Cell Shape","Marginal Adhesion","Single Epithelial Cell Size","Bare Nuclei","Bland Chromatin","Normal Nucleoli","Mitoses","Class"])

# %% [markdown]
# 2. mostrar las primeras 10 lineas

# %%
data.head(10)
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
# 5             1017122                8                       10
# 6             1018099                1                        1
# 7             1018561                2                        1
# 8             1033078                2                        1
# 9             1033078                4                        2
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
# 5                        10                  8                            7
# 6                         1                  1                            2
# 7                         2                  1                            2
# 8                         1                  1                            2
# 9                         1                  1                            2
#
#   Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0           1                3                1        1      2
# 1          10                3                2        1      2
# 2           2                3                1        1      2
# 3           4                3                7        1      2
# 4           1                3                1        1      2
# 5          10                9                7        1      4
# 6          10                3                1        1      2
# 7           1                3                1        1      2
# 8           1                1                1        5      2
# 9           1                2                1        1      2

# %% [markdown]
# 3. mostrar las ultimas lineas

# %%
data.tail(10)
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 689              654546                1                        1
# 690              654546                1                        1
# 691              695091                5                       10
# 692              714039                3                        1
# 693              763235                3                        1
# 694              776715                3                        1
# 695              841769                2                        1
# 696              888820                5                       10
# 697              897471                4                        8
# 698              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 689                         1                  1                            2
# 690                         1                  3                            2
# 691                        10                  5                            4
# 692                         1                  1                            2
# 693                         1                  1                            2
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 689           1                1                1        8      2
# 690           1                1                1        1      2
# 691           5                4                4        1      4
# 692           1                1                1        1      2
# 693           1                2                1        2      2
# 694           2                1                1        1      2
# 695           1                1                1        1      2
# 696           3                8               10        2      4
# 697           4               10                6        1      4
# 698           5               10                4        1      4

# %% [markdown]
# 4. muestre las dimensiones del DF

# %%
data.shape
# Out:
# (699, 11)

# %% [markdown]
# 5. muestre las estadísticas del DataFrame

# %%
est = pd.DataFrame(data);
est.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.990000e+02       699.000000               699.000000
# mean         1.071704e+06         4.417740                 3.134478
# std          6.170957e+05         2.815741                 3.051459
# min          6.163400e+04         1.000000                 1.000000
# 25%          8.706885e+05         2.000000                 1.000000
# 50%          1.171710e+06         4.000000                 1.000000
# 75%          1.238298e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                699.000000         699.000000
# mean                   3.207439           2.806867
# std                    2.971913           2.855379
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# 50%                    1.000000           1.000000
# 75%                    5.000000           4.000000
# max                   10.000000          10.000000
#
#        Single Epithelial Cell Size  Bland Chromatin  Normal Nucleoli  \
# count                   699.000000       699.000000       699.000000
# mean                      3.216023         3.437768         2.866953
# std                       2.214300         2.438364         3.053634
# min                       1.000000         1.000000         1.000000
# 25%                       2.000000         2.000000         1.000000
# 50%                       2.000000         3.000000         1.000000
# 75%                       4.000000         5.000000         4.000000
# max                      10.000000        10.000000        10.000000
#
#           Mitoses       Class
# count  699.000000  699.000000
# mean     1.589413    2.689557
# std      1.715078    0.951273
# min      1.000000    2.000000
# 25%      1.000000    2.000000
# 50%      1.000000    2.000000
# 75%      1.000000    4.000000
# max     10.000000    4.000000

# %% [markdown]
# 6. muestre todas las columnas del DF

# %%
est.columns
# Out:
# Index(['Sample code number', 'Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %% [markdown]
# 7. Escribir el DF a un archivo tipo json llamado breast-cancer-wisconsin.data.json

# %%
result = data.to_json(orient="index")
with open('breast-cancer-wisconsin.data.json', 'w') as file:json.dump(result, file, indent=4)
result
# Out:
# '{"0":{"Sample code number":1000025,"Clump Thickness":5,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"1","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"1":{"Sample code number":1002945,"Clump Thickness":5,"Uniformity of Cell Size":4,"Uniformity of Cell Shape":4,"Marginal Adhesion":5,"Single Epithelial Cell Size":7,"Bare Nuclei":"10","Bland Chromatin":3,"Normal Nucleoli":2,"Mitoses":1,"Class":2},"2":{"Sample code number":1015425,"Clump Thickness":3,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"2","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"3":{"Sample code number":1016277,"Clump Thickness":6,"Uniformity of Cell Size":8,"Uniformity of Cell Shape":8,"Marginal Adhesion":1,"Single Epithelial Cell Size":3,"Bare Nuclei":"4","Bland Chromatin":3,"Normal Nucleoli":7,"Mitoses":1,"Class":2},"4":{"Sample code number":1017023,"Clump Thickness":4,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":3,"Single Epithelial Cell Size":2,"Bare Nuclei":"1","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"5":{"Sample code number":1017122,"Clump Thickness":8,"Uniformity of Cell Size":10,"Uniformity of Cell Shape":10,"Marginal Adhesion":8,"Single Epithelial Cell Size":7,"Bare Nuclei":"10","Bland Chromatin":9,"Normal Nucleoli":7,"Mitoses":1,"Class":4},"6":{"Sample code number":1018099,"Clump Thickness":1,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"10","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"7":{"Sample code number":1018561,"Clump Thickness":2,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":2,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"1","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"8":{"Sample code number":1033078,"Clump Thickness":2,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"1","Bland Chromatin":1,"Normal Nucleoli":1,"Mitoses":5,"Class":2},"9":{"Sample code number":1033078,"Clump Thickness":4,"Uniformity of Cell Size":2,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"1","Bland Chromatin":2,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"10":{"Sample code number":1035283,"Clump Thickness":1,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":1,"Bare Nuclei":"1","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"11":{"Sample code number":1036172,"Clump Thickness":2,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"1","Bland Chromatin":2,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"12":{"Sample code number":1041801,"Clump Thickness":5,"Uniformity of Cell Size":3,"Uniformity of Cell Shape":3,"Marginal Adhesion":3,"Single Epithelial Cell Size":2,"Bare Nuclei":"3","Bland Chromatin":4,"Normal Nucleoli":4,"Mitoses":1,"Class":4},"13":{"Sample code number":1043999,"Clump Thickness":1,"Uniformity of Cell Size":1,"Uniformity of Cell Shape":1,"Marginal Adhesion":1,"Single Epithelial Cell Size":2,"Bare Nuclei":"3","Bland Chromatin":3,"Normal Nucleoli":1,"Mitoses":1,"Class":2},"14":{"Sample code number":1044572,"Clump Thickness":8,"Uniformity of Cell Size":7,"Uniformity of Cell Shape":5,"Marginal Adhesion":10,"Single Epithelial Cell Size":7,"Bare Nuclei":"9","Bland Chromatin":5,"Normal Nucleoli":5,"Mitoses":4,"Class":4},"15":{"Sample code number":1047630,"Clump Thickness":7,"Uniformity of Cell Size":4,"Uniformity of Cell Shape":6,"Marginal Adhesion":4,"Single Epithelial Cell Size":6,"Bare Nuclei":"1","Bland Chromatin":4,"Normal Nucleoli":3,"Mitoses":1,"Class":4},"16":{"Sample code number":1048672,"Clump Thicknes ...

# %% [markdown]
# 8. -muestre los tipos de datos del DF

# %%
data.dtypes
# Out:
# Sample code number              int64
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %% [markdown]
# 9. muestre las filas que tienen al menos un Nan y cuentelas

# %%
data.isnull().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# 10. reemplace los valores Nan por la media en las columnas numericas y almacenelo en el dataframe original

# %%
df = pd.DataFrame(data)
media = df['Class'].mean()
df['Class'].fillna(media)
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 694    2
# 695    2
# 696    4
# 697    4
# 698    4
# Name: Class, Length: 699, dtype: int64

# %% [markdown]
# 11.  Construya una variable dummy para la columna class (2= benigno, 4= maligno) en un Dataframe llamado DF_class

# %%
DF_class = pd.get_dummies(data["Class"])
DF_class.columns=['Benigno','Maligno']
dat = pd.DataFrame(DF_class);
dat
# Out:
#      Benigno  Maligno
# 0          1        0
# 1          1        0
# 2          1        0
# 3          1        0
# 4          1        0
# ..       ...      ...
# 694        1        0
# 695        1        0
# 696        0        1
# 697        0        1
# 698        0        1
#
# [699 rows x 2 columns]

# %% [markdown]
# 12. una el DF_class como columnas del Df datos

# %%
df = pd.DataFrame(data)
df = df.drop(['Class'],axis=1)
f  = pd.concat([df,dat], axis = 1)
f
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1000025                5                        1
# 1               1002945                5                        4
# 2               1015425                3                        1
# 3               1016277                6                        8
# 4               1017023                4                        1
# ..                  ...              ...                      ...
# 694              776715                3                        1
# 695              841769                2                        1
# 696              888820                5                       10
# 697              897471                4                        8
# 698              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Benigno  Maligno
# 0             1                3                1        1        1        0
# 1            10                3                2        1        1        0
# 2             2                3                1        1        1        0
# 3             4                3                7        1        1        0
# 4             1                3                1        1        1        0
# ..          ...              ...              ...      ...      ...      ...
# 694           2                1                1        1        1        0
# 695           1                1                1        1        1        0
# 696           3                8               10        2        0        1
# 697           4               10                6        1        0        1
# 698           5               10                4        1        0        1
#
# [699 rows x 12 columns]

# %% [markdown]
# 13. Muestre el histograma de cada columna

# %%
f.plot(kind='hist')

# %% [markdown]
# 14. Realice el diagrama de caja y bigotes de todas las columnas

# %%
f[["Sample code number","Clump Thickness","Uniformity of Cell Size","Uniformity of Cell Shape","Marginal Adhesion","Single Epithelial Cell Size","Bare Nuclei","Bland Chromatin","Normal Nucleoli","Mitoses","Benigno"]].boxplot()

# %% [markdown]
# 15. Cree un nuevo DF sin la columna class llamado datos_sin_class

# %%
datos = pd.DataFrame(data)
datos_sin_class = datos.drop(['Class'],axis=1)
datos_sin_class
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1000025                5                        1
# 1               1002945                5                        4
# 2               1015425                3                        1
# 3               1016277                6                        8
# 4               1017023                4                        1
# ..                  ...              ...                      ...
# 694              776715                3                        1
# 695              841769                2                        1
# 696              888820                5                       10
# 697              897471                4                        8
# 698              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses
# 0             1                3                1        1
# 1            10                3                2        1
# 2             2                3                1        1
# 3             4                3                7        1
# 4             1                3                1        1
# ..          ...              ...              ...      ...
# 694           2                1                1        1
# 695           1                1                1        1
# 696           3                8               10        2
# 697           4               10                6        1
# 698           5               10                4        1
#
# [699 rows x 10 columns]

# %% [markdown]
# 16. Muestre la fila 4 y 15 de datos

# %%
datos.iloc[[4,15]]
# Out:
#     Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 4              1017023                4                        1
# 15             1047630                7                        4
#
#     Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 4                          1                  3                            2
# 15                         6                  4                            6
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 4            1                3                1        1      2
# 15           1                4                3        1      4

# %% [markdown]
# 17. muestre la fila 8 y 10 con solo las columnas 1, 3, 6 de datos

# %%
condicion = datos.loc[:,['Sample code number', 'Clump Thickness', 'Single Epithelial Cell Size']] 
condicion.iloc[0:10]
# Out:
#    Sample code number  Clump Thickness  Single Epithelial Cell Size
# 0             1000025                5                            2
# 1             1002945                5                            7
# 2             1015425                3                            2
# 3             1016277                6                            3
# 4             1017023                4                            2
# 5             1017122                8                            7
# 6             1018099                1                            2
# 7             1018561                2                            2
# 8             1033078                2                            2
# 9             1033078                4                            2

# %% [markdown]
# 18. muestre las filas 11, 15, 18 con las columnas de datos Sample code number y Clump Thickness

# %%
condicion = datos.loc[:,['Sample code number', 'Clump Thickness']] 
condicion.iloc[[11,15,18]]
# Out:
#     Sample code number  Clump Thickness
# 11             1036172                2
# 15             1047630                7
# 18             1050670               10

# %% [markdown]
# 19. Realice una grafica tipo scatter que muestre la relacion entre "class" y "Single Epithelial Cell Size"

# %%
datos.plot(kind="scatter", x="Class", y="Single Epithelial Cell Size")

# %% [markdown]
# 20. muestre las filas cuya "Single Epithelial Cell Size" sea mayor a 5

# %%
condicion = datos[datos['Single Epithelial Cell Size']>5]
condicion
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-1a49291baf89> in <module>
# ----> 1 condicion = datos[datos['Single Epithelial Cell Size']>5]
#       2 condicion
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      55         result = libops.vec_compare(x.ravel(), y, op)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#      59
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'
